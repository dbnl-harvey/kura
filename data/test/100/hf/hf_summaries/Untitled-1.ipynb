# %%
import pandas as pd

df = pd.read_parquet("../../../../../data/test/10000/parquet/parquet_summaries.parquet")

# %%
df.to_csv("./summaries.csv")
# Out:
#                      chat_id  \
# 0           90_claude-v1_352
# 1           87_claude-v1_246
# 2          91_alpaca-13b_384
# 3     91_vicuna-13b-v1.2_434
# 4     87_vicuna-13b-v1.2_245
# ...                      ...
# 9995         82_llama-13b_77
# 9996   82_vicuna-13b-v1.2_82
# 9997        83_llama-13b_109
# 9998  92_vicuna-13b-v1.2_485
# 9999            86_gpt-4_220
#
#                                                 summary  \
# 0     The user requested grammatical corrections for...
# 1     The user requested a captivating short story b...
# 2     The conversation involves a user asking an AI ...
# 3     The conversation involves a user asking about ...
# 4     The conversation involves a user requesting a ...
# ...                                                 ...
# 9995  The user requested a professional email draft ...
# 9996  The user requested a professional and concise ...
# 9997  The user requested a concise blog post outline...
# ...
